# %%
# %pip install numpy
# %pip install pyopengl
# %pip install pyopencv2
# %pip install pandas

# %%
import scipy
import pandas as pd
import opencv2 as cv2
from OpenGL.GL import *
import glfw
import pyrr
import math
import time
import numpy as np
import os
import random

print(f"Got here")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import scipy
# ----> 2 import pandas
#       3 import opencv2
#       4 from OpenGL.GL import *
#
# ModuleNotFoundError: No module named 'pandas'
